# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajithkumar9047/Takehome-user-using-ml/blob/main/Takehome_user.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Read csv file as dataframe

# %%
df=pd.read_csv("/content/takehome_users.csv",encoding='utf-8', encoding_errors='ignore')
df1=pd.read_csv("/content/takehome_user_engagement.csv")

# %%
df1
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30      1.0      1.0
# 1       2013-11-15 03:45:04      2.0      1.0
# 2       2013-11-29 03:45:04      2.0      1.0
# 3       2013-12-09 03:45:04      2.0      1.0
# 4       2013-12-25 03:45:04      2.0      1.0
# ...                     ...      ...      ...
# 150465  2013-04-15 20:39:46   8679.0      1.0
# 150466  2013-04-20 20:39:46   8679.0      1.0
# 150467  2013-04-24 20:39:46   8679.0      1.0
# 150468  2013-04-29 20:39:46   8679.0      1.0
# 150469   2013-04-30 20:39:4      NaN      NaN
#
# [150470 rows x 3 columns]

# %% [markdown]
# # seperate date from datafreame and insert into new column

# %%
df1["time"] = pd.to_datetime(df1['time_stamp']).dt.date
df1
# Out:
#                  time_stamp  user_id  visited        time
# 0       2014-04-22 03:53:30      1.0      1.0  2014-04-22
# 1       2013-11-15 03:45:04      2.0      1.0  2013-11-15
# 2       2013-11-29 03:45:04      2.0      1.0  2013-11-29
# 3       2013-12-09 03:45:04      2.0      1.0  2013-12-09
# 4       2013-12-25 03:45:04      2.0      1.0  2013-12-25
# ...                     ...      ...      ...         ...
# 150465  2013-04-15 20:39:46   8679.0      1.0  2013-04-15
# 150466  2013-04-20 20:39:46   8679.0      1.0  2013-04-20
# 150467  2013-04-24 20:39:46   8679.0      1.0  2013-04-24
# 150468  2013-04-29 20:39:46   8679.0      1.0  2013-04-29
# 150469   2013-04-30 20:39:4      NaN      NaN  2013-04-30
#
# [150470 rows x 4 columns]

# %% [markdown]
# # Find unique date and remove same date from dataframe

# %%
q=df1.time.unique()

# %%
q

# %% [markdown]
# # Get pre-defined unique date value of data's from dataframe

# %%
df2=(df1.loc[df1['time'].isin(q)])
df2
# Out:
#                  time_stamp  user_id  visited        time
# 0       2014-04-22 03:53:30      1.0      1.0  2014-04-22
# 1       2013-11-15 03:45:04      2.0      1.0  2013-11-15
# 2       2013-11-29 03:45:04      2.0      1.0  2013-11-29
# 3       2013-12-09 03:45:04      2.0      1.0  2013-12-09
# 4       2013-12-25 03:45:04      2.0      1.0  2013-12-25
# ...                     ...      ...      ...         ...
# 150465  2013-04-15 20:39:46   8679.0      1.0  2013-04-15
# 150466  2013-04-20 20:39:46   8679.0      1.0  2013-04-20
# 150467  2013-04-24 20:39:46   8679.0      1.0  2013-04-24
# 150468  2013-04-29 20:39:46   8679.0      1.0  2013-04-29
# 150469   2013-04-30 20:39:4      NaN      NaN  2013-04-30
#
# [150470 rows x 4 columns]

# %% [markdown]
# # Convert date to weeks and insert into new column

# %%
week_val= pd.to_datetime(df2["time"])
result = week_val.dt.week
result
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
# 0         17
# 1         46
# 2         48
# 3         50
# 4         52
#           ..
# 150465    16
# 150466    16
# 150467    17
# 150468    18
# 150469    18
# Name: time, Length: 150470, dtype: int64

# %%
df2.insert(1, "week_no", result)
df2
# Out:
#                  time_stamp  week_no  user_id  visited        time
# 0       2014-04-22 03:53:30       17      1.0      1.0  2014-04-22
# 1       2013-11-15 03:45:04       46      2.0      1.0  2013-11-15
# 2       2013-11-29 03:45:04       48      2.0      1.0  2013-11-29
# 3       2013-12-09 03:45:04       50      2.0      1.0  2013-12-09
# 4       2013-12-25 03:45:04       52      2.0      1.0  2013-12-25
# ...                     ...      ...      ...      ...         ...
# 150465  2013-04-15 20:39:46       16   8679.0      1.0  2013-04-15
# 150466  2013-04-20 20:39:46       16   8679.0      1.0  2013-04-20
# 150467  2013-04-24 20:39:46       17   8679.0      1.0  2013-04-24
# 150468  2013-04-29 20:39:46       18   8679.0      1.0  2013-04-29
# 150469   2013-04-30 20:39:4       18      NaN      NaN  2013-04-30
#
# [150470 rows x 5 columns]

# %%
df2['year'] = pd.DatetimeIndex(df2['time']).year
df2
# Out:
#                  time_stamp  week_no  user_id  visited        time  year
# 0       2014-04-22 03:53:30       17      1.0      1.0  2014-04-22  2014
# 1       2013-11-15 03:45:04       46      2.0      1.0  2013-11-15  2013
# 2       2013-11-29 03:45:04       48      2.0      1.0  2013-11-29  2013
# 3       2013-12-09 03:45:04       50      2.0      1.0  2013-12-09  2013
# 4       2013-12-25 03:45:04       52      2.0      1.0  2013-12-25  2013
# ...                     ...      ...      ...      ...         ...   ...
# 150465  2013-04-15 20:39:46       16   8679.0      1.0  2013-04-15  2013
# 150466  2013-04-20 20:39:46       16   8679.0      1.0  2013-04-20  2013
# 150467  2013-04-24 20:39:46       17   8679.0      1.0  2013-04-24  2013
# 150468  2013-04-29 20:39:46       18   8679.0      1.0  2013-04-29  2013
# 150469   2013-04-30 20:39:4       18      NaN      NaN  2013-04-30  2013
#
# [150470 rows x 6 columns]

# %% [markdown]
# # **Get year and month in seperate column**

# %%
import datetime

# %%
df2['y_m']= list(zip(df2['week_no'], df2['year']))

# %%
df2.head(20)
# Out:
#              time_stamp  week_no  user_id  visited        time  year  \
# 0   2014-04-22 03:53:30       17      1.0      1.0  2014-04-22  2014
# 1   2013-11-15 03:45:04       46      2.0      1.0  2013-11-15  2013
# 2   2013-11-29 03:45:04       48      2.0      1.0  2013-11-29  2013
# 3   2013-12-09 03:45:04       50      2.0      1.0  2013-12-09  2013
# 4   2013-12-25 03:45:04       52      2.0      1.0  2013-12-25  2013
# 5   2013-12-31 03:45:04        1      2.0      1.0  2013-12-31  2013
# 6   2014-01-08 03:45:04        2      2.0      1.0  2014-01-08  2014
# 7   2014-02-03 03:45:04        6      2.0      1.0  2014-02-03  2014
# 8   2014-02-08 03:45:04        6      2.0      1.0  2014-02-08  2014
# 9   2014-02-09 03:45:04        6      2.0      1.0  2014-02-09  2014
# 10  2014-02-13 03:45:04        7      2.0      1.0  2014-02-13  2014
# 11  2014-02-16 03:45:04        7      2.0      1.0  2014-02-16  2014
# 12  2014-03-09 03:45:04       10      2.0      1.0  2014-03-09  2014
# ...

# %%
 data=df2.groupby(["user_id","y_m"])["visited"].count().reset_index()
 data.head(20)
# Out:
#     user_id         y_m  visited
# 0       1.0  (17, 2014)        1
# 1       2.0   (1, 2013)        1
# 2       2.0   (2, 2014)        1
# 3       2.0   (6, 2014)        3
# 4       2.0   (7, 2014)        2
# 5       2.0  (10, 2014)        1
# 6       2.0  (11, 2014)        1
# 7       2.0  (14, 2014)        1
# 8       2.0  (46, 2013)        1
# 9       2.0  (48, 2013)        1
# 10      2.0  (50, 2013)        1
# 11      2.0  (52, 2013)        1
# 12      3.0  (12, 2013)        1
# 13      4.0  (21, 2013)        1
# 14      5.0   (4, 2013)        1
# 15      6.0  (51, 2013)        1
# 16      7.0  (51, 2012)        1
# 17     10.0   (1, 2013)        1
# 18     10.0   (1, 2014)        4
# 19     10.0   (2, 2014)        4

# %% [markdown]
# # Find adopted user who visites greater than or equal to the times

# %%
adopted_user=data.loc[data["visited"]>=3]
adopted_user.head(20)
# Out:
#     user_id         y_m  visited
# 3       2.0   (6, 2014)        3
# 18     10.0   (1, 2014)        4
# 19     10.0   (2, 2014)        4
# 21     10.0   (3, 2014)        6
# 23     10.0   (4, 2014)        6
# 25     10.0   (5, 2014)        6
# 27     10.0   (6, 2014)        3
# 29     10.0   (7, 2014)        6
# 31     10.0   (8, 2014)        7
# 32     10.0   (9, 2013)        3
# 33     10.0   (9, 2014)        7
# 35     10.0  (10, 2014)        7
# 37     10.0  (11, 2014)        7
# 39     10.0  (12, 2014)        7
# 41     10.0  (13, 2014)        7
# 43     10.0  (14, 2014)        6
# 44     10.0  (15, 2013)        3
# 45     10.0  (15, 2014)        5
# 47     10.0  (16, 2014)        7
# 48     10.0  (17, 2013)        3

# %%
data['adopted_user'] = data['visited'].apply(lambda x:"adopted_user" if x>=3 else "non adopted_user")

# %%
data
# Out:
#        user_id         y_m  visited      adopted_user
# 0          1.0  (17, 2014)        1  non adopted_user
# 1          2.0   (1, 2013)        1  non adopted_user
# 2          2.0   (2, 2014)        1  non adopted_user
# 3          2.0   (6, 2014)        3      adopted_user
# 4          2.0   (7, 2014)        2  non adopted_user
# ...        ...         ...      ...               ...
# 50071   8679.0  (39, 2012)        1  non adopted_user
# 50072   8679.0  (40, 2012)        1  non adopted_user
# 50073   8679.0  (43, 2012)        1  non adopted_user
# 50074   8679.0  (51, 2012)        1  non adopted_user
# 50075   8679.0  (52, 2012)        1  non adopted_user
#
# [50076 rows x 4 columns]

# %%
df.rename(columns={"object_id":"user_id"},inplace =True)
df.head()
# Out:
#    user_id        creation_time               name  \
# 0        1  2014-04-22 03:53:30     Clausen August
# 1        2  2013-11-15 03:45:04      Poole Matthew
# 2        3  2013-03-19 23:14:52  Bottrill Mitchell
# 3        4  2013-05-21 08:09:28    Clausen Nicklas
# 4        5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
df
# Out:
#        user_id        creation_time               name  \
# 0            1  2014-04-22 03:53:30     Clausen August
# 1            2  2013-11-15 03:45:04      Poole Matthew
# 2            3  2013-03-19 23:14:52  Bottrill Mitchell
# 3            4  2013-05-21 08:09:28    Clausen Nicklas
# 4            5  2013-01-17 10:14:20          Raw Grace
# ...        ...                  ...                ...
# 11995    11996  2013-09-06 06:14:15       Meier Sophia
# 11996    11997  2013-01-10 18:28:37      Fisher Amelie
# 11997    11998  2014-04-27 12:45:16        Haynes Jake
# 11998    11999  2012-05-31 11:55:59       Faber Annett
# 11999    12000  2014-01-26 08:57:12          Lima Thas
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %% [markdown]
# # Merge two data frame for more details about adopted users

# %%
merged_data=pd.merge(df,data,how="right",on="user_id")

# %%
merged_data
# Out:
#        user_id        creation_time            name                     email  \
# 0            1  2014-04-22 03:53:30  Clausen August  AugustCClausen@yahoo.com
# 1            2  2013-11-15 03:45:04   Poole Matthew    MatthewPoole@gustr.com
# 2            2  2013-11-15 03:45:04   Poole Matthew    MatthewPoole@gustr.com
# 3            2  2013-11-15 03:45:04   Poole Matthew    MatthewPoole@gustr.com
# 4            2  2013-11-15 03:45:04   Poole Matthew    MatthewPoole@gustr.com
# ...        ...                  ...             ...                       ...
# 50071     8679  2012-07-14 20:39:46       Berg Erik   ErikBerg@jourrapide.com
# 50072     8679  2012-07-14 20:39:46       Berg Erik   ErikBerg@jourrapide.com
# 50073     8679  2012-07-14 20:39:46       Berg Erik   ErikBerg@jourrapide.com
# 50074     8679  2012-07-14 20:39:46       Berg Erik   ErikBerg@jourrapide.com
# 50075     8679  2012-07-14 20:39:46       Berg Erik   ErikBerg@jourrapide.com
#
# ...

# %% [markdown]
# # Visualize adopted user

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
x = ['Adopted_users','Non_adopted_users']
y = [(data.adopted_user.value_counts()[1]),(data.adopted_user.value_counts()[0])]
plt.bar(x,y,color='g',edgecolor='r',width=0.5)

plt.xlabel("Type of users",color='blue')
plt.ylabel("Number of users",color='blue')
plt.title("Visualisation on type of users",color='m',fontsize=14)
plt.show()

# %%
df3 = data[(data['visited']>=3)]
df3.head()
# Out:
#     user_id        y_m  visited  adopted_user
# 3       2.0  (6, 2014)        3  adopted_user
# 18     10.0  (1, 2014)        4  adopted_user
# 19     10.0  (2, 2014)        4  adopted_user
# 21     10.0  (3, 2014)        6  adopted_user
# 23     10.0  (4, 2014)        6  adopted_user

# %%
q = merged_data.groupby(['creation_source']).size().values
p = merged_data.groupby(['creation_source']).size().index
y = np.array(q)
x = np.array(p)
plt.pie(y, labels = x,explode= (0,0,0.1,0,0), autopct='%1.2f%%',shadow=True)
plt.title("Percentage distribution of types of creation source", color = 'm',fontsize=16)
plt.show()
